# %% [markdown]
# <a href="https://colab.research.google.com/github/entc-17-fyp-20/CM_Normal_Behaviour_Modeling/blob/samal/Data_Augmentation.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# multivariate data preparation
from numpy import array
from numpy import hstack
import pandas as pd
import numpy as np
from sklearn import preprocessing
from datetime import datetime

from keras.models import Sequential
from keras.layers import Dense
from keras.layers import Flatten, BatchNormalization, Dropout, LocallyConnected2D, LeakyReLU, ReLU
from keras.layers.convolutional import Conv2D
from keras.callbacks import EarlyStopping, ModelCheckpoint

import plotly.graph_objects as go
import matplotlib.pyplot as plt

import plotly.express as px
import plotly.graph_objects as go

# %%
#@title Select Dataset New { display-mode: "form" }
turbine = 'T01' #@param ["T01", "T02","T03","T22","T34","T54"]
path = '/content/drive/MyDrive/Merged/' + turbine + '.csv'
#path = '/content/drive/MyDrive/Wind Datasets/after concat/T22.csv'
df = pd.read_csv(path)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 75320 entries, 0 to 75319
# Data columns (total 15 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   Date_Time                     75320 non-null  object
#  1   Ambient_Temperature           75320 non-null  int64
#  2   Gear_Bearing_Temperature      75320 non-null  int64
#  3   Gear_Oil_Tempeature           75320 non-null  int64
#  4   Generator_Bearing_Tempeature  75320 non-null  int64
#  5   Generator_RPM                 75320 non-null  float64
#  6   Possible_Active_Power         75320 non-null  float64
#  7   Active_Power                  75320 non-null  float64
#  8   Reactive_Power                75320 non-null  float64
#  9   Voltage1                      75320 non-null  float64
#  10  Voltage2                      75320 non-null  float64
#  11  Voltage3                      75320 non-null  float64
# ...

# %%
a=40000
b=42000
df_trunc = df[a:b]
#df_trunc['scaling'] = (df_trunc.index-a)*0.1
df_trunc['scaling'] = df_trunc['Active_Power']*0.1
df['scaling']=df_trunc['scaling']
df['scaling'] = df['scaling'].fillna(df['Active_Power'])
#df['scaling']=df['scaling']+df['Active_Power']
fig = px.line(df, x="Date_Time" , y='scaling') 
fig.show()
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:5: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
df
# Out:
#                  Date_Time  Ambient_Temperature  ...  Wind_Speed  scaling
# 0       2017-01-01 0:00:00                   -9  ...         6.0    190.1
# 1       2017-01-01 0:10:00                   -9  ...         5.0    282.6
# 2       2017-01-01 0:20:00                   -9  ...         5.6    334.3
# 3       2017-01-01 0:30:00                  -10  ...         5.6    312.6
# 4       2017-01-01 0:40:00                  -10  ...         5.2    272.6
# ...                    ...                  ...  ...         ...      ...
# 75315  2018-12-29 18:10:00                   -3  ...         7.1    876.4
# 75316  2018-12-29 18:20:00                   -3  ...         6.9    763.1
# 75317  2018-12-29 18:30:00                   -3  ...         7.7    902.4
# 75318  2018-12-29 18:40:00                   -3  ...         8.0   1450.4
# 75319  2018-12-29 18:50:00                   -4  ...         9.8   1223.9
#
# [75320 rows x 16 columns]
